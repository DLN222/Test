# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import time
from random import randint

# %%
xlsx_rm = "EPA_Results_3271.xlsx"

# %%
ny_results = pd.read_excel(xlsx_rm)
ny_results
# Out:
#                        FacName                         FacStreet  \
# 0                   ALFRED RMC                    546 CLARK ROAD
# 1          ALL ABOUT RECYCLING             451 OLD NEPPERHAN AVE
# 2                 ALLEGANY RMC             4419 S NINE MILE ROAD
# 3         AMENIA SAND & GRAVEL                 299 LEEDSVILLE RD
# 4     AMERICAN CONCRETE OF WNY                  500 RICHFIELD ST
# ..                         ...                               ...
# 178        W F SAUNDERS & SONS                5126 ONONDAGA ROAD
# 179            WADLER BROS INC                       47293 RT 28
# 180  WAYNE CONCRETE AT ASHFORD                 7020 HENRIETTA RD
# 181               WELLES PIT#2  ELMIRA AIRPORT RD NORTH OF RT 17
# 182   WEST NYACK ASPHALT PLANT                        CRUSHER RD
#
#             FacCity FacState    RegistryID FacSNCFlg  FacQtrsWithNC  \
# 0    ALFRED STATION       NY  110045506751         N              1
# ...

# %%
ny_results.shape
# Out:
# (183, 13)

# %%
column_ids = ny_results['RegistryID']

# %%
print(column_ids)
# Out:
# 0      110045506751
# 1      110071337424
# 2      110045506779
# 3      110007147024
# 4      110022522466
#            ...
# 178    110001578980
# 179    110039185618
# 180    110040436418
# 181    110019375237
# 182    110007151009
# Name: RegistryID, Length: 183, dtype: int64

# %%
base_url = "https://echo.epa.gov/detailed-facility-report?fid="

# %%
url_list = []

for column_id in column_ids:
    print(f"{base_url}{column_id}")
    
url_list
# Out:
# https://echo.epa.gov/detailed-facility-report?fid=110045506751
# https://echo.epa.gov/detailed-facility-report?fid=110071337424
# https://echo.epa.gov/detailed-facility-report?fid=110045506779
# https://echo.epa.gov/detailed-facility-report?fid=110007147024
# https://echo.epa.gov/detailed-facility-report?fid=110022522466
# https://echo.epa.gov/detailed-facility-report?fid=110064222988
# https://echo.epa.gov/detailed-facility-report?fid=110033200480
# https://echo.epa.gov/detailed-facility-report?fid=110019714727
# https://echo.epa.gov/detailed-facility-report?fid=110010414774
# https://echo.epa.gov/detailed-facility-report?fid=110007338434
# https://echo.epa.gov/detailed-facility-report?fid=110019714790
# https://echo.epa.gov/detailed-facility-report?fid=110070114187
# https://echo.epa.gov/detailed-facility-report?fid=110011025461
# https://echo.epa.gov/detailed-facility-report?fid=110071363613
# https://echo.epa.gov/detailed-facility-report?fid=110001569927
# ...

# %%
test_url = "https://echo.epa.gov/detailed-facility-report?fid=110045506751"

# %%
# !pip install html5lib
# Out:
# DEPRECATION: Loading egg at /Users/GSB/anaconda3/lib/python3.11/site-packages/dlib-19.24.99-py3.11-macosx-10.9-x86_64.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# ...

# %%
#df_list = pd.read_html(test_url)
#df_list

response = requests.get(test_url)
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<html lang="en" dir="ltr" prefix="content: http://purl.org/rss/1.0/modules/content/  dc: http://purl.org/dc/terms/  foaf: http://xmlns.com/foaf/0.1/  og: http://ogp.me/ns#  rdfs: http://www.w3.org/2000/01/rdf-schema#  schema: http://schema.org/  sioc: http://rdfs.org/sioc/ns#  sioct: http://rdfs.org/sioc/types#  skos: http://www.w3.org/2004/02/skos/core#  xsd: http://www.w3.org/2001/XMLSchema# ">\n  <head>\n    <!-- Google Tag Manager -->\n    <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\n    new Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\n    j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n    \'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n    })(window,document,\'script\',\'dataLayer\',\'GTM-L8ZB\');</script>\n    <!-- End Google Tag Manager -->\n    <meta charset="utf-8" />\n<meta name="Generator" content="Drupal 10 (https://www.drupal.org)" />
# ...

# %%
response.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en" dir="ltr" prefix="content: http://purl.org/rss/1.0/modules/content/  dc: http://purl.org/dc/terms/  foaf: http://xmlns.com/foaf/0.1/  og: http://ogp.me/ns#  rdfs: http://www.w3.org/2000/01/rdf-schema#  schema: http://schema.org/  sioc: http://rdfs.org/sioc/ns#  sioct: http://rdfs.org/sioc/types#  skos: http://www.w3.org/2004/02/skos/core#  xsd: http://www.w3.org/2001/XMLSchema# ">\n  <head>\n    <!-- Google Tag Manager -->\n    <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\n    new Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\n    j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n    \'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n    })(window,document,\'script\',\'dataLayer\',\'GTM-L8ZB\');</script>\n    <!-- End Google Tag Manager -->\n    <meta charset="utf-8" />\n<meta name="Generator" content="Drupal 10 (https://www.drupal.org)" /
# ...

# %%
type(response.content)
# Out:
# bytes

# %%
soup = BeautifulSoup(response.text, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html dir="ltr" lang="en" prefix="content: http://purl.org/rss/1.0/modules/content/  dc: http://purl.org/dc/terms/  foaf: http://xmlns.com/foaf/0.1/  og: http://ogp.me/ns#  rdfs: http://www.w3.org/2000/01/rdf-schema#  schema: http://schema.org/  sioc: http://rdfs.org/sioc/ns#  sioct: http://rdfs.org/sioc/types#  skos: http://www.w3.org/2004/02/skos/core#  xsd: http://www.w3.org/2001/XMLSchema# ">
# <head>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-L8ZB');</script>
# <!-- End Google Tag Manager -->
# <meta charset="utf-8"/>
# <meta content="Drupal 10 (https://www.drupal.org)" name="Generator"/>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en" prefix="content: http://purl.org/rss/1.0/modules/content/  dc: http://purl.org/dc/terms/  foaf: http://xmlns.com/foaf/0.1/  og: http://ogp.me/ns#  rdfs: http://www.w3.org/2000/01/rdf-schema#  schema: http://schema.org/  sioc: http://rdfs.org/sioc/ns#  sioct: http://rdfs.org/sioc/types#  skos: http://www.w3.org/2004/02/skos/core#  xsd: http://www.w3.org/2001/XMLSchema# ">
#  <head>
#   <!-- Google Tag Manager -->
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-L8ZB');
#   </script>
#   <!-- End Google Tag Manager -->
#   <meta charset="utf-8"/>
#   <meta content="Drupal 10 (https://www.drupal.org)" name="Generator"/>
# ...

# %%
soup.find("dl")

# %%
tag = soup.find_all("ul", class_="menu")
tag
# echo-grid-one-third
#<section class="echo-subsection echo-grid-one-third print-hide"><div class="echo-map-container embed-container"><div class="shared-facility-map esri-view-div dfr-facility-map esri-view esri-view-height-xsmall esri-view-height-less-than-small esri-view-height-less-than-medium esri-view-height-less-than-large esri-view-height-less-than-xlarge esri-view-width-xsmall esri-view-width-less-than-small esri-view-width-less-than-medium esri-view-width-less-than-large esri-view-width-less-than-xlarge esri-view-orientation-landscape"><div class="esri-view-root"><div class="esri-view-surface esri-view-surface--touch-none" role="application" tabindex="0" aria-label="Map View"><canvas style="width: 343px; height: 240px; display: block;" aria-label="Map Canvas" width="549" height="384"></canvas></div><div class="esri-overlay-surface"><div style="visibility: hidden;"></div></div><div class="esri-ui calcite-mode-light" lang="en-US" style="inset: 0px;"><div class="esri-ui-inner-container esri-ui-corner-container" style="inset: 15px 15px 30px;"><div class="esri-ui-top-left esri-ui-corner"><div class="esri-component esri-zoom esri-widget"><calcite-button class="esri-widget--button" title="Zoom in" alignment="center" appearance="solid" kind="neutral" icon-start="plus" scale="m" type="button" width="auto"></calcite-button><calcite-button class="esri-widget--button" title="Zoom out" alignment="center" appearance="solid" kind="neutral" icon-start="minus" scale="m" type="button" width="auto"></calcite-button></div><div class="esri-component esri-home esri-widget"><calcite-button class="esri-widget--button" title="Default map view" alignment="center" appearance="solid" kind="neutral" icon-start="home" scale="m" type="button" width="auto"></calcite-button></div></div><div class="esri-ui-top-right esri-ui-corner"><div class="esri-component esri-fullscreen esri-widget"><calcite-button class="esri-widget--button" title="Enter fullscreen" alignment="center" appearance="solid" kind="neutral" icon-start="zoom-out-fixed" scale="m" type="button" width="auto"></calcite-button></div><div class="esri-component esri-expand esri-widget"><div class="esri-expand__toggle"><calcite-button class="esri-widget--button" title="Map Layers" aria-controls="calcite-popover-0479b32d-9a6b-e6fd-5aee-49689023b688" aria-expanded="false" alignment="center" appearance="solid" kind="neutral" scale="s" type="button" width="auto"><calcite-icon class="esri-collapse__icon" aria-hidden="true" icon="layers" scale="s"></calcite-icon></calcite-button></div><calcite-popover style="visibility: hidden; pointer-events: none; position: fixed;" aria-hidden="true" aria-label="Map Layers" aria-live="polite" calcite-hydrated-hidden="" id="calcite-popover-0479b32d-9a6b-e6fd-5aee-49689023b688" role="dialog" offset-distance="6" offset-skidding="0" overlay-positioning="fixed" placement="left-start" scale="m"><div class="esri-expand__popover-content"><div class="esri-expand__content-container"><div class="esri-layer-list esri-widget esri-widget--panel"><calcite-flow><calcite-flow-item heading-level="2" overlay-positioning="absolute"><calcite-list data-layer-type="operational-1934761d90c-object-21" group="operational-1934761d90c-object-21" filter-placeholder="" filter-text="" selection-mode="none" selection-appearance="border"><calcite-list-item class="esri-layer-list__item" data-layer-id="Colleges" id="1934761d88a-object-14" title="Colleges/Universities"><div class="esri-layer-list__item-content" slot="content">Colleges/Universities</div><calcite-icon class="esri-layer-list__status-indicator" slot="actions-end" aria-hidden="true" icon="bullet-point" scale="s"></calcite-icon><calcite-action class="esri-layer-list__visible-toggle" slot="actions-end" title="Visibility" appearance="transparent" scale="s"><calcite-icon aria-hidden="true" icon="view-hide" scale="s"></calcite-icon></calcite-action><calcite-action slot="actions-end" title="Legend" appearance="transparent" disabled="" scale="s" aria-disabled="true"></calcite-action></calcite-list-item><calcite-list-item class="esri-layer-list__item" data-layer-id="Schools K-12" id="1934761d887-object-13" title="Schools K-12 Public and Private"><div class="esri-layer-list__item-content" slot="content">Schools K-12 Public and Private</div><calcite-icon class="esri-layer-list__status-indicator" slot="actions-end" aria-hidden="true" icon="bullet-point" scale="s"></calcite-icon><calcite-action class="esri-layer-list__visible-toggle" slot="actions-end" title="Visibility" appearance="transparent" scale="s"><calcite-icon aria-hidden="true" icon="view-hide" scale="s"></calcite-icon></calcite-action><calcite-action slot="actions-end" title="Legend" appearance="transparent" disabled="" scale="s" aria-disabled="true"></calcite-action></calcite-list-item><calcite-list-item class="esri-layer-list__item" data-layer-id="Hospitals" id="1934761d87f-object-8" title="Hospitals"><div class="esri-layer-list__item-content" slot="content">Hospitals</div><calcite-icon class="esri-layer-list__status-indicator" slot="actions-end" aria-hidden="true" icon="bullet-point" scale="s"></calcite-icon><calcite-action class="esri-layer-list__visible-toggle" slot="actions-end" title="Visibility" appearance="transparent" scale="s"><calcite-icon aria-hidden="true" icon="view-hide" scale="s"></calcite-icon></calcite-action><calcite-action slot="actions-end" title="Legend" appearance="transparent" disabled="" scale="s" aria-disabled="true"></calcite-action></calcite-list-item></calcite-list></calcite-flow-item></calcite-flow></div></div></div></calcite-popover></div></div><div class="esri-ui-bottom-left esri-ui-corner"><div class="esri-component esri-scale-bar esri-widget"><div class="esri-scale-bar__bar-container esri-scale-bar__bar-container--line"><div class="esri-scale-bar__line esri-scale-bar__line--top" style="width: 113px;"></div><div class="esri-scale-bar__label-container esri-scale-bar__label-container--line esri-scale-bar__label-container--top"><div class="esri-scale-bar__label">50 m</div></div></div><div class="esri-scale-bar__bar-container esri-scale-bar__bar-container--line"><div class="esri-scale-bar__line esri-scale-bar__line--bottom" style="width: 138px;"></div><div class="esri-scale-bar__label-container esri-scale-bar__label-container--line esri-scale-bar__label-container--bottom"><div class="esri-scale-bar__label">200 ft</div></div></div></div></div><div class="esri-ui-bottom-right esri-ui-corner"></div></div><div class="esri-ui-inner-container esri-ui-manual-container"><div class="esri-component esri-attribution esri-widget" dir="ltr"><div class="esri-attribution__sources esri-interactive" tabindex="0">New York State, Maxar, Microsoft | Esri Community Maps Contributors, data.pa.gov, © OpenStreetMap, Microsoft, Esri, TomTom, Garmin, SafeGraph, GeoTechnologies, Inc, METI/NASA, USGS, EPA, NPS, US Census Bureau, USDA, USFWS</div><div class="esri-attribution__powered-by">Powered by <a class="esri-attribution__link" href="https://www.esri.com/" rel="noreferrer" target="_blank">Esri</a></div></div></div></div></div><div class="esri-view-user-storage"></div></div></div></section>
# Out:
# [<ul class="menu menu--main">
#  <li class="menu__item"><a class="menu__link" href="https://www.epa.gov/environmental-topics">Environmental
#                  Topics</a></li>
#  <li class="menu__item"><a class="menu__link" href="https://www.epa.gov/laws-regulations">Laws &amp;
#                  Regulations</a></li>
#  <li class="menu__item"><a class="menu__link" href="https://www.epa.gov/report-violation">Report a
#                  Violation</a></li>
#  <li class="menu__item"><a class="menu__link" href="https://www.epa.gov/aboutepa">About EPA</a></li>
#  </ul>,
#  <ul class="menu sf-menu sf-main sf-horizontal sf-style-none" id="superfish-main">
# ...

# %%
<section class="echo-subsection echo-grid-two-thirds"><div class="echo-grid-one-half"><div class="mobile-hide"><h4>ALFRED RMC</h4><h4>546 CLARK ROAD, ALFRED STATION, NY 14803<div class="echo-info-modal display-inline margin-left-1"><button class="usa-button usa-button--unstyled" type="button" title="Facility Address Caveat"><span class="fa fa-info-circle"></span></button></div></h4></div><dl class="echo-dl"><div class="echo-dict-group"><dt class="echo-dt"><span><abbr title="Facility Registry Service">FRS</abbr> ID</span></dt><dd class="echo-dd">110045506751</dd></div><div class="echo-dict-group"><dt class="echo-dt">EPA Region</dt><dd class="echo-dd">02</dd></div><div class="echo-dict-group"><dt class="echo-dt">Latitude</dt><dd class="echo-dd">42.289</dd></div><div class="echo-dict-group"><dt class="echo-dt">Longitude</dt><dd class="echo-dd">-77.754</dd></div><div class="echo-dict-group"><dt class="echo-dt">Locational Data Source</dt><dd class="echo-dd">NPDES</dd></div><div class="echo-dict-group"><dt class="echo-dt">Industries</dt><dd class="echo-dd">--</dd></div><div class="echo-dict-group"><dt class="echo-dt">Indian Country</dt><dd class="echo-dd">N</dd></div></dl></div><div class="echo-grid-one-half print-hide"><div class="mobile-hide"><section class="echo-help-container titles-not-displayed"><a href="/help/reports/dfr-data-dictionary#facsum" target="_blank" rel="noopener noreferrer" class="echo-help-link echo-link"><span class="echo-icon icon-data-dictionary"></span> </a></section></div><dl class="echo-dl"><h4>Related Reports</h4><div class="echo-dict-group echo-dict-link"><a href="/trends/loading-tool/reports/dmr-pollutant-loading/?year=2024&amp;permit_id=NYR00F100" class="echo-link" target="_blank" title="CWA Pollutant Loading Report" aria-label=""><span class="echo-report-icon  fa-stack fa-2x"><span class="fa-solid fa-square fa-stack-2x" style="color: rgb(7, 100, 141);"></span><span class="letter-icon fa-solid fa-l fa-stack-1x fa-inverse"></span></span><label class="echo-icon-label">CWA Pollutant Loading Report</label></a></div><div class="echo-dict-group echo-dict-link"><a href="/effluent-charts#NYR00F100" class="echo-link" target="_blank" title="CWA Effluent Charts" aria-label=""><span class="echo-report-icon  fa-stack fa-2x"><span class="fa-solid fa-square fa-stack-2x" style="color: rgb(63, 87, 166);"></span><span class="letter-icon fa-solid fa-e fa-stack-1x fa-inverse"></span></span><label class="echo-icon-label">CWA Effluent Charts</label></a></div><div class="echo-dict-group echo-dict-link"><a href="/trends/loading-tool/reports/effluent-exceedances/?permit_id=NYR00F100" class="echo-link" target="_blank" title="CWA DMR Exceedances Report" aria-label=""><span class="echo-report-icon  fa-stack fa-2x"><span class="fa-solid fa-square fa-stack-2x" style="color: rgb(134, 67, 129);"></span><span class="letter-icon fa-solid fa-x fa-stack-1x fa-inverse"></span></span><label class="echo-icon-label">CWA DMR Exceedances Report</label></a></div><div class="echo-dict-group echo-dict-link"><a href="#" title="View Envirofacts Reports">View Envirofacts Reports</a></div><div class="echo-dict-group echo-dict-link"><a href="#community">View EJ Data in the Community section of the report</a></div><div class="echo-dict-group echo-dict-link"><a class="external" target="_blank" href="#">EJScreen Community Report</a> </div></dl></div></section>
# Out:
# None

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en" prefix="content: http://purl.org/rss/1.0/modules/content/  dc: http://purl.org/dc/terms/  foaf: http://xmlns.com/foaf/0.1/  og: http://ogp.me/ns#  rdfs: http://www.w3.org/2000/01/rdf-schema#  schema: http://schema.org/  sioc: http://rdfs.org/sioc/ns#  sioct: http://rdfs.org/sioc/types#  skos: http://www.w3.org/2004/02/skos/core#  xsd: http://www.w3.org/2001/XMLSchema# ">
#  <head>
#   <!-- Google Tag Manager -->
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-L8ZB');
#   </script>
#   <!-- End Google Tag Manager -->
#   <meta charset="utf-8"/>
#   <meta content="Drupal 10 (https://www.drupal.org)" name="Generator"/>
# ...
